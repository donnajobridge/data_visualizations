# %%
import pandas as pd
import numpy as np
import seaborn as sns
import math
import matplotlib.pyplot as plt

# %%
emo=pd.read_csv('emo.csv')
emo.head()
# Out:
#    Subj    RT  response code affect up/in  old/new
# 0    90  1110              2      l    up        2
# 1    90  1835              2      l    up        2
# 2    90  1377              1      l    up        2
# 3    90   922              1      s    up        1
# 4    90  2969              1      l    in        2

# %%
accuracy=emo['response code']==emo['old/new']

# %%
emo['accuracy']=accuracy.map({True:1, False:0})
emo['up/in']=emo['up/in'].map({'up':'Whole', 'in':'Features'})
emo['affect']=emo['affect'].map({'h':'Positive', 's':'Negative', 'l':'Lure'})

# %%
pivot=pd.pivot_table(emo, values='accuracy', index=['affect', 'up/in'], columns=['old/new'])

# %%
pd.DataFrame(emo.groupby(['Subj', 'up/in', 'old/new'])['response code'].count())
# Out:
#                        response code
# Subj up/in    old/new
# 90   Features 1                   16
#               2                   16
#      Whole    1                   16
#               2                   16
# 92   Features 1                   16
#               2                   16
#      Whole    1                   16
#               2                   16
# 93   Features 1                   16
#               2                   16
#      Whole    1                   16
#               2                   16
# 94   Features 1                   16
#               2                   16
#      Whole    1                   16
#               2                   16
# 95   Features 1                   16
#               2                   16
#      Whole    1                   16
#               2                   16
# 96   Features 1                   16
#               2                   16
#      Whole    1                   16
#               2                   16
# 130  Features 1                   16
#               2                   16
#      Whole    1                   16
#               2                   16
# 136  Features 1                   16
#               2                   16
# ...                              ...
# 519  Whole    1                   16
#               2                   16
# 524  Features 1                   16
#               2                   16
#      Whole    1                   16
#               2                   16
# 528  Features 1                   16
#               2                   16
#      Whole    1                   16
#               2                   16
# 529  Features 1                   16
#               2                   16
#      Whole    1                   16
#               2                   16
# 537  Features 1                   16
#               2                   16
#      Whole    1                   16
#               2                   16
# 544  Features 1                   16
#               2                   16
#      Whole    1                   16
#               2                   16
# 554  Features 1                   16
#               2                   16
#      Whole    1                   16
#               2                   16
# 567  Features 1                   16
#               2                   16
#      Whole    1                   16
#               2                   16
#
# [180 rows x 1 columns]

# %%
means=pd.DataFrame(emo.groupby(['Subj', 'affect', 'up/in'])['accuracy'].mean())

# %%
means.reset_index(inplace=True)

# %%
means.melt(id_vars=['Subj', 'affect', 'up/in'])
# Out:
#      Subj    affect     up/in  variable   value
# 0      90      Lure  Features  accuracy  0.3750
# 1      90      Lure     Whole  accuracy  0.6875
# 2      90  Negative  Features  accuracy  0.7500
# 3      90  Negative     Whole  accuracy  0.6250
# 4      90  Positive  Features  accuracy  0.5000
# 5      90  Positive     Whole  accuracy  0.3750
# 6      92      Lure  Features  accuracy  0.5000
# 7      92      Lure     Whole  accuracy  0.5625
# 8      92  Negative  Features  accuracy  0.7500
# 9      92  Negative     Whole  accuracy  0.5000
# 10     92  Positive  Features  accuracy  0.7500
# 11     92  Positive     Whole  accuracy  0.8750
# 12     93      Lure  Features  accuracy  0.3750
# 13     93      Lure     Whole  accuracy  0.5000
# 14     93  Negative  Features  accuracy  1.0000
# 15     93  Negative     Whole  accuracy  0.6250
# 16     93  Positive  Features  accuracy  0.8750
# 17     93  Positive     Whole  accuracy  0.7500
# 18     94      Lure  Features  accuracy  0.2500
# 19     94      Lure     Whole  accuracy  0.6250
# 20     94  Negative  Features  accuracy  0.5000
# 21     94  Negative     Whole  accuracy  0.2500
# 22     94  Positive  Features  accuracy  0.3750
# 23     94  Positive     Whole  accuracy  0.7500
# 24     95      Lure  Features  accuracy  0.3750
# 25     95      Lure     Whole  accuracy  0.6875
# 26     95  Negative  Features  accuracy  0.6250
# 27     95  Negative     Whole  accuracy  0.6250
# 28     95  Positive  Features  accuracy  0.7500
# 29     95  Positive     Whole  accuracy  0.7500
# ..    ...       ...       ...       ...     ...
# 240   529      Lure  Features  accuracy  0.3125
# 241   529      Lure     Whole  accuracy  0.8750
# 242   529  Negative  Features  accuracy  0.8750
# 243   529  Negative     Whole  accuracy  0.8750
# 244   529  Positive  Features  accuracy  0.6250
# 245   529  Positive     Whole  accuracy  0.7500
# 246   537      Lure  Features  accuracy  0.3125
# 247   537      Lure     Whole  accuracy  0.4375
# 248   537  Negative  Features  accuracy  0.8750
# 249   537  Negative     Whole  accuracy  1.0000
# 250   537  Positive  Features  accuracy  0.7500
# 251   537  Positive     Whole  accuracy  0.8750
# 252   544      Lure  Features  accuracy  0.8125
# 253   544      Lure     Whole  accuracy  1.0000
# 254   544  Negative  Features  accuracy  0.7500
# 255   544  Negative     Whole  accuracy  0.7500
# 256   544  Positive  Features  accuracy  0.6250
# 257   544  Positive     Whole  accuracy  0.7500
# 258   554      Lure  Features  accuracy  0.5000
# 259   554      Lure     Whole  accuracy  0.8125
# 260   554  Negative  Features  accuracy  0.7500
# 261   554  Negative     Whole  accuracy  0.5000
# 262   554  Positive  Features  accuracy  0.5000
# 263   554  Positive     Whole  accuracy  0.6250
# 264   567      Lure  Features  accuracy  0.0625
# 265   567      Lure     Whole  accuracy  0.3125
# 266   567  Negative  Features  accuracy  0.5000
# 267   567  Negative     Whole  accuracy  0.8750
# 268   567  Positive  Features  accuracy  0.7500
# 269   567  Positive     Whole  accuracy  0.7500
#
# [270 rows x 5 columns]

# %%
means['affect'].unique()
# Out:
# array(['Lure', 'Negative', 'Positive'], dtype=object)

# %%
old=means[means['affect']!='Lure']
new=means[means['affect']=='Lure']

# %%
new['fa']=1-new['accuracy']
new_in=new[new['up/in']=='Features']
new_up=new[new['up/in']=='Whole']
new_in.rename(columns={'fa':'fa_in'}, inplace=True)
new_up.rename(columns={'fa':'fa_up'}, inplace=True)
new_in
new_up.set_index('Subj', inplace=True)
new_in.set_index('Subj',inplace=True)

new=pd.concat([new_in['fa_in'], new_up['fa_up']], axis=1)
new
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/frame.py:3027: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)
#        fa_in   fa_up
# Subj
# 90    0.6250  0.3125
# 92    0.5000  0.4375
# 93    0.6250  0.5000
# 94    0.7500  0.3750
# 95    0.6250  0.3125
# 96    0.2500  0.1875
# 130   0.2500  0.3750
# 136   0.2500  0.1875
# 147   0.6875  0.1250
# 149   0.2500  0.4375
# 154   0.4375  0.2500
# 155   0.9375  0.3750
# 156   0.3750  0.3750
# 166   0.4375  0.4375
# 177   0.4375  0.5000
# 179   0.3125  0.3125
# 183   0.6250  0.2500
# 189   0.4375  0.0625
# 190   0.1875  0.6250
# 193   0.7500  0.4375
# 204   0.3750  0.4375
# 209   0.3750  0.3750
# 210   0.5625  0.6250
# 211   0.8750  0.6875
# 350   0.8750  0.3750
# 353   0.4375  0.1875
# 359   0.5000  0.3125
# 360   0.6875  0.1250
# 411   0.1250  0.1875
# 415   0.3750  0.2500
# 416   0.3750  0.2500
# 428   0.3125  0.3125
# 448   0.4375  0.2500
# 471   0.3750  0.4375
# 475   0.5000  0.3750
# 488   0.2500  0.1250
# 510   0.6250  0.3125
# 519   0.6250  0.1875
# 524   0.1875  0.1250
# 528   0.6250  0.3125
# 529   0.6875  0.1250
# 537   0.6875  0.5625
# 544   0.1875  0.0000
# 554   0.5000  0.1875
# 567   0.9375  0.6875

# %%
happy_old=old[old['affect']=='Positive']
sad_old=old[old['affect']=='Negative']
old_wide=pd.merge(happy_old, sad_old, on='Subj')

# %%
inv = happy_old[happy_old['up/in']=='Features']
up = happy_old[happy_old['up/in']=='Whole']

up.rename(columns={'accuracy':'hap_up_accuracy'}, inplace=True)
inv.rename(columns={'accuracy':'hap_inv_accuracy'}, inplace=True)

up.set_index('Subj', inplace=True)
inv.set_index('Subj', inplace=True)

up=up[['hap_up_accuracy']]
inv=inv[['hap_inv_accuracy']]

happy_hits=pd.concat([up, inv], axis=1)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/frame.py:3027: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)

# %%
inv = sad_old[sad_old['up/in']=='Features']
up = sad_old[sad_old['up/in']=='Whole']

up.rename(columns={'accuracy':'sad_up_accuracy'}, inplace=True)
inv.rename(columns={'accuracy':'sad_inv_accuracy'}, inplace=True)

up.set_index('Subj', inplace=True)
inv.set_index('Subj', inplace=True)

up=up[['sad_up_accuracy']]
inv=inv[['sad_inv_accuracy']]

sad_hits=pd.concat([up, inv], axis=1)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/frame.py:3027: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)

# %%
sad_hits
def adjust_hits_fa(array, resp, affect):
    if resp=='hit':

    for ind, row in hits_fa.iterrows():
        halfhit=.5/16
        halffa=.5/32
        hit=row['hit']
        fa=row['fa']
        if hit==1:
            hit=1-halfhit
        if hit==0:
            hit=halfhit
        if fa==1:
            fa=1-halffa
        if fa==0:
            fa=halffa
# Out:
#       sad_up_accuracy  sad_inv_accuracy
# Subj
# 90              0.625             0.750
# 92              0.500             0.750
# 93              0.625             1.000
# 94              0.250             0.500
# 95              0.625             0.625
# 96              0.875             0.500
# 130             0.875             0.625
# 136             0.875             0.875
# 147             0.750             0.625
# 149             0.875             0.500
# 154             0.375             0.750
# 155             0.750             0.875
# 156             0.875             0.875
# 166             0.375             0.625
# 177             0.875             0.750
# 179             0.625             0.375
# 183             0.750             0.625
# 189             0.375             0.500
# 190             0.625             0.625
# 193             0.750             0.625
# 204             0.625             0.500
# 209             0.875             0.875
# 210             0.625             0.750
# 211             1.000             1.000
# 350             0.875             0.875
# 353             0.750             0.375
# 359             1.000             0.250
# 360             0.625             0.875
# 411             0.375             0.500
# 415             1.000             0.500
# 416             0.875             0.625
# 428             0.250             0.625
# 448             0.375             0.625
# 471             0.625             0.875
# 475             0.750             0.750
# 488             0.375             0.500
# 510             0.625             0.625
# 519             0.125             0.500
# 524             0.750             0.750
# 528             0.500             0.750
# 529             0.875             0.875
# 537             1.000             0.875
# 544             0.750             0.750
# 554             0.500             0.750
# 567             0.875             0.500

# %%
hits_fa=pd.concat([happy_hits, sad_hits, new], axis=1)
hits_fa.columns
# Out:
# Index(['hap_up_accuracy', 'hap_inv_accuracy', 'sad_up_accuracy',
#        'sad_inv_accuracy', 'fa_in', 'fa_up'],
#       dtype='object')

# %%
for ind, row in hits_fa.iterrows():
    halfhit=.5/row['old_count']
    halffa=.5/row['new_count']
    hit=row['hit']
    fa=row['fa']
    if hit==1:
        hit=1-halfhit
    if hit==0:
        hit=halfhit
    if fa==1:
        fa=1-halffa
    if fa==0:
        fa=halffa
    dprime=Z(hit)-Z(fa)    
    old_new_means.loc[ind,'adjusted_hit']=hit
    old_new_means.loc[ind,'adjusted_fa']=fa
    old_new_means.loc[ind,'dprime']=dprime

# %%
uplist=[hap_up_accuracy, sad_up_accuracy]
inlist=[hap_inv_accuracy, sad_inv_accuracy]
def get_dprime_tidy(condlist, affect, hits_fa):
    newdf=pd.DataFrame()
    for ind, col in enumerate(condlist):
        
        
        newdf['dprime']=tmp[col]/tmp[condname +'_all']
        newdf['locs']=ind+1
        newdf['cxt']=cxt
        newdf['cond']=cond
        props=props.append(newdf)
    return props

act0_prop=get_prop_tidy(act0, 'act_cxt0', tmp, 0, 'act')
act1_prop=get_prop_tidy(act1, 'act_cxt1', tmp, 1, 'act')
pas0_prop=get_prop_tidy(pas0, 'pas_cxt0', tmp, 0, 'pas')
pas1_prop=get_prop_tidy(pas1, 'pas_cxt1', tmp, 1, 'pas')

props_tidy=act0_prop.append([act1_prop, pas0_prop, pas1_prop])

# %%
viosplit=sns.violinplot(x="up/in", y="accuracy", hue='affect', split=True, data=old, palette="Set2")
plt.xlabel('')
plt.ylabel('Proportion Correct')
plt.tight_layout()
plt.legend(loc='upper center')
# viosplitfig=viosplit.get_figure()
# viosplitfig.savefig('emo_viosplit.png')

# %%
pivot

# %%
bar=sns.barplot(x="up/in", y="accuracy", hue='affect', data=old, palette="Set2")
plt.legend(loc='upper center')
plt.xlabel('')
plt.ylabel('Proportion Correct')
plt.tight_layout()

barfig=bar.get_figure()
barfig.savefig('emo_bar.png')

line_x_neg = [-.2, .8]
line_y_neg = [.672222, .672222]

line_x_pos = [.2, 1.2]
line_y_pos = [.591667, .758333]

bar.plot(line_x_pos, line_y_pos, c='orange', alpha=.5)
bar.plot(line_x_neg, line_y_neg, c='green', alpha=.5)

bar.get_xlim()

# %%
sns.factorplot(x="affect", y="accuracy", hue="affect",
               col="up/in", data=old, kind="bar", palette='Set2');
sns.factorplot(x="affect", y="accuracy", hue="affect",
               col="up/in", data=old, kind="strip", jitter=True, palette='Set2');
plt.title(['Features', 'Whole'])

# %%
sns.boxplot(x="up/in", y="accuracy", hue='affect', data=old, palette="Set2")

# %%
line=sns.pointplot(x="up/in", y="accuracy", hue='affect', jitter=True, data=old, palette="Set2", );
plt.ylim([0.5,.9])

# %%
pivot

# %%
vio=sns.violinplot(x="affect", y="accuracy", data=old[old['up/in']=='Whole'], palette='Set2');

line_x_neg = [-.2, .2]
line_y_neg = [.672222, .672222]

line_x_pos = [.8, 1.2]
line_y_pos = [.758333, .758333]

vio.plot(line_x_pos, line_y_pos, c='k')
vio.plot(line_x_neg, line_y_neg, c='k')

plt.title('Holistic')
vio.get_xlim()

# %%
vio=sns.violinplot(x="affect", y="accuracy", data=old[old['up/in']=='Features'], palette='Set2');
vio.ylim=[0, 1]
line_x_neg = [-.2, .2]
line_y_neg = [.672222, .672222]

line_x_pos = [.8, 1.2]
line_y_pos = [0.591667, 0.591667]

vio.plot(line_x_pos, line_y_pos, c='k')
vio.plot(line_x_neg, line_y_neg, c='k')

plt.title('Features')

vio.get_xlim()

# %%
strip=sns.factorplot(x="affect", y="accuracy", hue="affect",
               col="up/in", data=old, kind="strip", jitter=True, palette='Set2');

# %%
swarm=sns.factorplot(x="affect", y="accuracy", hue="affect",
               col="up/in", data=old, kind="swarm", palette='Set2');

# %%
barfig=bar.get_figure()
barfig.savefig('emo_bar.png')
