# %%
import pandas as pd
import numpy as np
import seaborn as sns
import math
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score

# %%
emo=pd.read_csv('emo.csv')
emo.head()
# Out:
#    Subj    RT  response code affect up/in  old/new
# 0    90  1110              2      l    up        2
# 1    90  1835              2      l    up        2
# 2    90  1377              1      l    up        2
# 3    90   922              1      s    up        1
# 4    90  2969              1      l    in        2

# %%
# emo['lure']=emo['affect']=='l'
score_list = []
for up_in, ldf in emo.groupby('up/in'):
    sad=ldf[ldf['affect'].isin(['l', 's'])]
    cm=confusion_matrix(sad['old/new'], sad['response code'])
#     cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    sns.heatmap(cm, cmap='Blues', annot=True, fmt='g')
    plt.title('Sad_'+str(up_in))
    plt.show()
    
    hap=ldf[ldf['affect'].isin(['l', 'h'])]
    cm=confusion_matrix(hap['old/new'], hap['response code'])
#     cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    sns.heatmap(cm, cmap='Reds', annot=True, fmt='g')
    plt.title('HAPPY_'+str(up_in))
    plt.show()
    
    
    srecall=recall_score(sad['old/new'], sad['response code'])
    sprecision=precision_score(sad['old/new'], sad['response code'])
    sf1=f1_score(sad['old/new'], sad['response code'])
    
    hrecall=recall_score(hap['old/new'], hap['response code'])
    hprecision=precision_score(hap['old/new'], hap['response code'])
    hf1=f1_score(hap['old/new'], hap['response code'])
    
    scores={'affect':'sad','up_in':up_in, 'recall':srecall, 'precision':sprecision, 'f1':sf1}
    score_list.append(scores)
    scores={'affect':'happy','up_in':up_in, 'recall':hrecall, 'precision':hprecision, 'f1':hf1}
    score_list.append(scores)
scoresdf=pd.DataFrame(score_list)

# %%
# emo['lure']=emo['affect']=='l'
sub_score_list = []
for sub_upin, ldf in emo.groupby(['Subj','up/in']):
    sub, upin = sub_upin
    sad=ldf[ldf['affect'].isin(['l', 's'])]
    hap=ldf[ldf['affect'].isin(['l', 'h'])]
    
    srecall=recall_score(sad['old/new'], sad['response code'])
    sprecision=precision_score(sad['old/new'], sad['response code'])
    sf1=f1_score(sad['old/new'], sad['response code'])
    
    hrecall=recall_score(hap['old/new'], hap['response code'])
    hprecision=precision_score(hap['old/new'], hap['response code'])
    hf1=f1_score(hap['old/new'], hap['response code'])
    
    scores={'sub':sub, 'affect':'sad','up_in':upin, 'recall':srecall, 'precision':sprecision, 'f1':sf1}
    sub_score_list.append(scores)
    scores={'sub':sub, 'affect':'happy','up_in':upin, 'recall':hrecall, 'precision':hprecision, 'f1':hf1}
    sub_score_list.append(scores)
sub_scoresdf=pd.DataFrame(sub_score_list)

# %%
sns.barplot(x='up_in', y='precision', hue='affect', data=sub_scoresdf, palette='Set2')
plt.title('Precision')
plt.show()
sns.barplot(x='up_in', y='recall', hue='affect', data=sub_scoresdf, palette='Set2')
plt.title('Recall')
plt.show()
sns.barplot(x='up_in', y='f1', hue='affect', data=sub_scoresdf, palette='Set2')
plt.title('F1')
plt.show()

# %%
# P's Reccomended Way to Summarize Trial df --> Subject df
summary_data = []
for group_ids, little_df in emo.groupby(['Subj', 'affect', 'up/in', 'lure']):
#     print(group_ids)
    # do a bunch of calculations
    this_data = {}
    summary_data.append(this_data)
# pd.DataFrame(summary_data)
# little_df

# %%
accuracy=emo['response code']==emo['old/new']
incorrect=emo['response code']!=emo['old/new']
# yes==emo['response code']==1

# add in precision: hits/hits+fa
# roc hits vs. false alarms
#bins positive/neg and up/in

# %%
emo['accuracy']=accuracy.map({True:1, False:0})
emo['incorrect']=incorrect.map({True:1, False:0})

emo['up/in']=emo['up/in'].map({'up':'Whole', 'in':'Features'})
emo['affect']=emo['affect'].map({'h':'Positive', 's':'Negative', 'l':'Lure'})

# %%
pivot=pd.pivot_table(emo, values='accuracy', index=['Subj', 'affect', 'up/in'], columns=['old/new'])

# %%
means=pd.DataFrame(emo.groupby(['Subj', 'affect', 'up/in'])['accuracy'].mean())
# sums=pd.DataFrame(emo.groupby(['Subj', 'affect', 'up/in'])['accuracy'].sum())
# counts=pd.DataFrame(emo.groupby(['Subj', 'affect', 'up/in'])['accuracy'].count())

# %%
# pd.concat([means.reset_index(), counts.reset_index(), sums.reset_index()], axis=1)
# Out:
#      Subj    affect     up/in  accuracy  Subj    affect     up/in  accuracy  \
# 0      90      Lure  Features    0.3750    90      Lure  Features        16
# 1      90      Lure     Whole    0.6875    90      Lure     Whole        16
# 2      90  Negative  Features    0.7500    90  Negative  Features         8
# 3      90  Negative     Whole    0.6250    90  Negative     Whole         8
# 4      90  Positive  Features    0.5000    90  Positive  Features         8
# 5      90  Positive     Whole    0.3750    90  Positive     Whole         8
# 6      92      Lure  Features    0.5000    92      Lure  Features        16
# 7      92      Lure     Whole    0.5625    92      Lure     Whole        16
# 8      92  Negative  Features    0.7500    92  Negative  Features         8
# 9      92  Negative     Whole    0.5000    92  Negative     Whole         8
# 10     92  Positive  Features    0.7500    92  Positive  Features         8
# ...

# %%
means.reset_index(inplace=True)
# Out:
#      Subj    affect     up/in  accuracy
# 0      90      Lure  Features    0.3750
# 1      90      Lure     Whole    0.6875
# 2      90  Negative  Features    0.7500
# 3      90  Negative     Whole    0.6250
# 4      90  Positive  Features    0.5000
# 5      90  Positive     Whole    0.3750
# 6      92      Lure  Features    0.5000
# 7      92      Lure     Whole    0.5625
# 8      92  Negative  Features    0.7500
# 9      92  Negative     Whole    0.5000
# 10     92  Positive  Features    0.7500
# 11     92  Positive     Whole    0.8750
# 12     93      Lure  Features    0.3750
# 13     93      Lure     Whole    0.5000
# 14     93  Negative  Features    1.0000
# 15     93  Negative     Whole    0.6250
# 16     93  Positive  Features    0.8750
# 17     93  Positive     Whole    0.7500
# 18     94      Lure  Features    0.2500
# 19     94      Lure     Whole    0.6250
# 20     94  Negative  Features    0.5000
# 21     94  Negative     Whole    0.2500
# ...

# %%
means['affect'].unique()
# Out:
# array(['Lure', 'Negative', 'Positive'], dtype=object)

# %%
old=means[means['affect']!='Lure']
new=means[means['affect']=='Lure']

# %%
new['fa']=1-new['accuracy']
new_in=new[new['up/in']=='Features']
new_up=new[new['up/in']=='Whole']
new_in.rename(columns={'fa':'fa_in'}, inplace=True)
new_up.rename(columns={'fa':'fa_up'}, inplace=True)
new_in
new_up.set_index('Subj', inplace=True)
new_in.set_index('Subj',inplace=True)

new=pd.concat([new_in['fa_in'], new_up['fa_up']], axis=1)
new
# Out:
# /Users/drdj/.pyenv/versions/3.6.5/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /Users/drdj/.pyenv/versions/3.6.5/lib/python3.6/site-packages/pandas/core/frame.py:3027: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)
#        fa_in   fa_up
# Subj
# 90    0.6250  0.3125
# 92    0.5000  0.4375
# 93    0.6250  0.5000
# 94    0.7500  0.3750
# 95    0.6250  0.3125
# 96    0.2500  0.1875
# 130   0.2500  0.3750
# 136   0.2500  0.1875
# ...

# %%
happy_old=old[old['affect']=='Positive']
sad_old=old[old['affect']=='Negative']
old_wide=pd.merge(happy_old, sad_old, on='Subj')

# %%
inv = happy_old[happy_old['up/in']=='Features']
up = happy_old[happy_old['up/in']=='Whole']

up.rename(columns={'accuracy':'hap_up_accuracy'}, inplace=True)
inv.rename(columns={'accuracy':'hap_inv_accuracy'}, inplace=True)

up.set_index('Subj', inplace=True)
inv.set_index('Subj', inplace=True)

up=up[['hap_up_accuracy']]
inv=inv[['hap_inv_accuracy']]

happy_hits=pd.concat([up, inv], axis=1)
# Out:
# /Users/drdj/.pyenv/versions/3.6.5/lib/python3.6/site-packages/pandas/core/frame.py:3027: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)

# %%
inv = sad_old[sad_old['up/in']=='Features']
up = sad_old[sad_old['up/in']=='Whole']

up.rename(columns={'accuracy':'sad_up_accuracy'}, inplace=True)
inv.rename(columns={'accuracy':'sad_inv_accuracy'}, inplace=True)

up.set_index('Subj', inplace=True)
inv.set_index('Subj', inplace=True)

up=up[['sad_up_accuracy']]
inv=inv[['sad_inv_accuracy']]

sad_hits=pd.concat([up, inv], axis=1)
# Out:
# /Users/drdj/.pyenv/versions/3.6.5/lib/python3.6/site-packages/pandas/core/frame.py:3027: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)

# %%
hits_fa=pd.concat([happy_hits, sad_hits, new], axis=1)
hits_fa
# Out:
#       hap_up_accuracy  hap_inv_accuracy  sad_up_accuracy  sad_inv_accuracy  \
# Subj
# 90              0.375             0.500            0.625             0.750
# 92              0.875             0.750            0.500             0.750
# 93              0.750             0.875            0.625             1.000
# 94              0.750             0.375            0.250             0.500
# 95              0.750             0.750            0.625             0.625
# 96              0.875             0.125            0.875             0.500
# 130             0.625             0.500            0.875             0.625
# 136             0.625             0.875            0.875             0.875
# 147             0.750             0.375            0.750             0.625
# 149             0.750             0.625            0.875             0.500
# 154             0.625             0.375            0.375             0.750
# ...

# %%
# sad_hits
# def adjust_hits_fa(array, resp, affect):
#     if resp=='hit':

#     for ind, row in hits_fa.iterrows():
#         halfhit=.5/16
#         halffa=.5/32
#         hit=row['hit']
#         fa=row['fa']
#         if hit==1:
#             hit=1-halfhit
#         if hit==0:
#             hit=halfhit
#         if fa==1:
#             fa=1-halffa
#         if fa==0:
#             fa=halffa
# Out:
#   File "<ipython-input-17-e1544a2b7cc5>", line 5
#     for ind, row in hits_fa.iterrows():
#       ^
# IndentationError: expected an indented block

# %%
hits_fa=pd.concat([happy_hits, sad_hits, new], axis=1)
hits_fa.columns
# Out:
# Index(['hap_up_accuracy', 'hap_inv_accuracy', 'sad_up_accuracy',
#        'sad_inv_accuracy', 'fa_in', 'fa_up'],
#       dtype='object')

# %%
# for ind, row in hits_fa.iterrows():
#     halfhit=.5/row['old_count']
#     halffa=.5/row['new_count']
#     hit=row['hit']
#     fa=row['fa']
#     if hit==1:
#         hit=1-halfhit
#     if hit==0:
#         hit=halfhit
#     if fa==1:
#         fa=1-halffa
#     if fa==0:
#         fa=halffa
#     dprime=Z(hit)-Z(fa)    
#     old_new_means.loc[ind,'adjusted_hit']=hit
#     old_new_means.loc[ind,'adjusted_fa']=fa
#     old_new_means.loc[ind,'dprime']=dprime

# %%
uplist=[hap_up_accuracy, sad_up_accuracy]
inlist=[hap_inv_accuracy, sad_inv_accuracy]
def get_dprime_tidy(condlist, affect, hits_fa):
    newdf=pd.DataFrame()
    for ind, col in enumerate(condlist):
        
        
        newdf['dprime']=tmp[col]/tmp[condname +'_all']
        newdf['locs']=ind+1
        newdf['cxt']=cxt
        newdf['cond']=cond
        props=props.append(newdf)
    return props

act0_prop=get_prop_tidy(act0, 'act_cxt0', tmp, 0, 'act')
act1_prop=get_prop_tidy(act1, 'act_cxt1', tmp, 1, 'act')
pas0_prop=get_prop_tidy(pas0, 'pas_cxt0', tmp, 0, 'pas')
pas1_prop=get_prop_tidy(pas1, 'pas_cxt1', tmp, 1, 'pas')

props_tidy=act0_prop.append([act1_prop, pas0_prop, pas1_prop])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-9aab36295168> in <module>()
# ----> 1 uplist=[hap_up_accuracy, sad_up_accuracy]
#       2 inlist=[hap_inv_accuracy, sad_inv_accuracy]
#       3 def get_dprime_tidy(condlist, affect, hits_fa):
#       4     newdf=pd.DataFrame()
#       5     for ind, col in enumerate(condlist):
#
# NameError: name 'hap_up_accuracy' is not defined

# %%
viosplit=sns.violinplot(x="up/in", y="accuracy", hue='affect', split=True, data=old, palette="Set2")
plt.xlabel('')
plt.ylabel('Proportion Correct')
plt.tight_layout()
plt.legend(loc='upper center')
# viosplitfig=viosplit.get_figure()
# viosplitfig.savefig('emo_viosplit.png')

# %%
pivot

# %%
bar=sns.barplot(x="up/in", y="accuracy", hue='affect', data=old, palette="Set2")
plt.legend(loc='upper center')
plt.xlabel('')
plt.ylabel('Proportion Correct')
plt.tight_layout()

barfig=bar.get_figure()
barfig.savefig('emo_bar.png')

line_x_neg = [-.2, .8]
line_y_neg = [.672222, .672222]

line_x_pos = [.2, 1.2]
line_y_pos = [.591667, .758333]

bar.plot(line_x_pos, line_y_pos, c='orange', alpha=.5)
bar.plot(line_x_neg, line_y_neg, c='green', alpha=.5)

bar.get_xlim()

# %%
sns.factorplot(x="affect", y="accuracy", hue="affect",
               col="up/in", data=old, kind="bar", palette='Set2');
sns.factorplot(x="affect", y="accuracy", hue="affect",
               col="up/in", data=old, kind="strip", jitter=True, palette='Set2');
plt.title(['Features', 'Whole'])

# %%
sns.boxplot(x="up/in", y="accuracy", hue='affect', data=old, palette="Set2")

# %%
line=sns.pointplot(x="up/in", y="accuracy", hue='affect', jitter=True, data=old, palette="Set2", );
plt.ylim([0.5,.9])

# %%
pivot

# %%
vio=sns.violinplot(x="affect", y="accuracy", data=old[old['up/in']=='Whole'], palette='Set2');

line_x_neg = [-.2, .2]
line_y_neg = [.672222, .672222]

line_x_pos = [.8, 1.2]
line_y_pos = [.758333, .758333]

vio.plot(line_x_pos, line_y_pos, c='k')
vio.plot(line_x_neg, line_y_neg, c='k')

plt.title('Holistic')
vio.get_xlim()

# %%
vio=sns.violinplot(x="affect", y="accuracy", data=old[old['up/in']=='Features'], palette='Set2');
vio.ylim=[0, 1]
line_x_neg = [-.2, .2]
line_y_neg = [.672222, .672222]

line_x_pos = [.8, 1.2]
line_y_pos = [0.591667, 0.591667]

vio.plot(line_x_pos, line_y_pos, c='k')
vio.plot(line_x_neg, line_y_neg, c='k')

plt.title('Features')

vio.get_xlim()

# %%
strip=sns.factorplot(x="affect", y="accuracy", hue="affect",
               col="up/in", data=old, kind="strip", jitter=True, palette='Set2');

# %%
swarm=sns.factorplot(x="affect", y="accuracy", hue="affect",
               col="up/in", data=old, kind="swarm", palette='Set2');

# %%
barfig=bar.get_figure()
barfig.savefig('emo_bar.png')
